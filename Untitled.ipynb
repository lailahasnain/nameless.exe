# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [i for i in range(101)]
y = [i**2 for i in x]

# %%
plt.figure(figsize=(15,5))
plt.plot(x,y)
plt.title('I love Dogs!')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')
